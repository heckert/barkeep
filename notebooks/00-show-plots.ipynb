# %%
# %load_ext autoreload
# %autoreload 2

# %%
import barkeep as bk
from barkeep.colors import normalize_rgb
from barkeep.datasets import test_df

# %%
bk.plot(test_df,
        groupby='group',
        count='bins',
        average='metric',
        average_type='mean',
        overall=True)
